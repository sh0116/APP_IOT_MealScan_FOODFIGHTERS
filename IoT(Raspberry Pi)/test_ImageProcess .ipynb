# %%
# !git clone https://github.com/osamhack2021/APP_IOT_AI_MilitaryCafeteria_FOODFIGHTERS.git
# Out:
# Cloning into 'APP_IOT_AI_MilitaryCafeteria_FOODFIGHTERS'...
# remote: Enumerating objects: 19311, done.
# remote: Counting objects: 100% (233/233), done.
# remote: Compressing objects: 100% (166/166), done.
# remote: Total 19311 (delta 104), reused 155 (delta 58), pack-reused 19078
# Receiving objects: 100% (19311/19311), 574.59 MiB | 19.29 MiB/s, done.
# Resolving deltas: 100% (5211/5211), done.
# Checking out files: 100% (8764/8764), done.

# %%
cd APP_IOT_AI_MilitaryCafeteria_FOODFIGHTERS/IoT(Raspberry Pi)/
# Out:
# /content/APP_IOT_AI_MilitaryCafeteria_FOODFIGHTERS/IoT(Raspberry Pi)

# %%
# !python3 test_ImageProcess.py
#per는 양의 정도를 가늠한 것으로 70_per image에 속해있다고 해서 절대! 실제 양이 70% 가지고 있는것은 아니다.
#4가지 per군(70,50,30,0)을 나눈 단위 정도라고 생각하면 될것같다.
# Out:
# 70_per : result
#  side_1 | side_2 | side_3 |  soup  |  rice  |
#  71.15  | 28.59  | 47.79  | 67.29  | 60.59  |
#
# 50_per : result
#  side_1 | side_2 | side_3 |  soup  |  rice  |
#  69.03  | 25.33  | 47.48  | 61.49  | 48.07  |
#
# 30_per : result
#  side_1 | side_2 | side_3 |  soup  |  rice  |
#  54.97  | 19.81  | 27.55  | 48.44  | 44.73  |
#
# 0_per : result
#  side_1 | side_2 | side_3 |  soup  |  rice  |
#  36.05  | 10.38  | 20.06  | 3.26  | 1.41  |

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 

per_list = ["70_per","50_per","30_per","0_per"]
dish_tag = ["_side_1","_side_2","_side_3","_soup","_rice"]
fig = plt.figure() # rows*cols 행렬의 i번째 subplot 생성
rows = 2
cols = 2

for tag in dish_tag:
  total_images = 4
  cnt = 1
  fig = plt.figure() # rows*cols 행렬의 i번째 subplot 생성
  rows = 2
  cols = 2
  print("\n {} : images".format(tag))
  for per in per_list:
    img = cv2.imread("asset/result_test_image/result_{}{}.png".format(per,tag))
    ax = fig.add_subplot(rows, cols, cnt)
    ax.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    ax.set_xlabel("result_{}{}.png".format(per,tag))
    ax.set_xticks([]), ax.set_yticks([])
    cnt+=1
  plt.show()
# Out:
#  _side_1 : images
#  _side_2 : images
#  _side_3 : images
#  _soup : images
#  _rice : images
